# %% [markdown]
# <a href="https://colab.research.google.com/github/fabianfoos/RedesNeuronales/blob/main/UTN_FRP_NN_Practica4_prePandemi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://www.frp.utn.edu.ar/info2/wp-content/uploads/2018/03/utn-parana.png" alt="UTN-FRP"/>
#
# <h1>Maestría en Minería de Datos</h1>
# <h2>Redes neuronales: Práctica 4</h2>
# <h3>Estudiantes: ...</h2>

# %% [markdown]
# # Configuración inicial
#
# Importar las librerías necesarias y configurar el entorno.

# %%
from datetime import datetime

import keras
import numpy as np
import yfinance as yf
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_percentage_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, GRU, LSTM

# %% [markdown]
# # Descarga y análisis de datos
# En este problema construiremos un modelo que genere predicciones respecto de un activo financiero. El activo que estaremos usando es el precio de cierre de la acción de YPF en la Bolsa de Comercio de Buenos Aires, y se pretende que el modelo sea capaz de generar la predicción del precio del cierre al comenzar ese mismo día.
#
# **Disclaimer**: *El equipo docente no recomienda, bajo ningún punto de vista, la utilización de este instrumento financiero ni de cualquier otro activo similar como elemento de inversión y/o ahorro. El uso de estos datos tiene fines puramente académicos y busca ser un medio para el aprendizaje y la aplicación de los temas vistos en este curso.*

# %%
# Descarga de datos históricos
ticker_symbol = "YPFD.BA"
start_date = "2015-01-01"
end_date = "2019-12-31"
ypf_data = yf.download(ticker_symbol, start=start_date, end=end_date)

close_prices = ypf_data['Close'].values.reshape(-1, 1)

def create_sequences(data, window_size):
    sequences = []
    targets = []
    for i in range(len(data) - window_size):
        sequences.append(data[i:i + window_size])
        targets.append(data[i + window_size])
    return np.array(sequences), np.array(targets)
# Out:
# /tmp/ipython-input-2099794188.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   ypf_data = yf.download(ticker_symbol, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Análisis descriptivo de los datos
#
# Realice un primer análisis para entender el comportamiento de la serie temporal que utilizaremos en este problema. Evalúe si existen valores nulos, si la serie de datos presenta estacionalidad, tendencia, etc.

# %%
# Análisis exploratorio inicial de la serie de precios de cierre
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose, STL
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Preparar serie con índice datetime
if 'ypf_data' in globals():
    df = ypf_data.copy()
else:
    # si no existe ypf_data, intentar reconstruir desde close_prices
    df = pd.DataFrame(close_prices, columns=['Close'])
    try:
        df.index = pd.to_datetime(ypf_data.index)
    except Exception:
        pass

# Asegurar datetime index y eliminar nulos
if not isinstance(df.index, pd.DatetimeIndex):
    df = df.reset_index()
    if 'Date' in df.columns:
        df['Date'] = pd.to_datetime(df['Date'])
        df = df.set_index('Date')

df = df[['Close']].copy()
print('Observaciones totales (incluyendo nulos):', len(df))
print('Rango de fechas: ', df.index.min(), 'a', df.index.max())
print('\nValores nulos por columna:')
print(df.isna().sum())

# Estadísticos básicos
print('\nEstadísticos descriptivos de Close:')
print(df['Close'].describe())

# Visualización de la serie
plt.figure(figsize=(12,4))
plt.plot(df['Close'], label='Close')
plt.title('Serie de precios de cierre')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.grid(True)
plt.legend()
plt.show()

# Rolling mean / std para observar tendencia y volatilidad
window = 30
rolling_mean = df['Close'].rolling(window=window).mean()
rolling_std = df['Close'].rolling(window=window).std()

# Asegurar arrays 1D para matplotlib.fill_between
x = df.index.to_numpy()
close_vals = df['Close'].to_numpy().ravel()
ma_vals = rolling_mean.to_numpy().ravel()
lower = (rolling_mean - rolling_std).to_numpy().ravel()
upper = (rolling_mean + rolling_std).to_numpy().ravel()

plt.figure(figsize=(12,4))
plt.plot(x, close_vals, alpha=0.5, label='Close')
plt.plot(x, ma_vals, color='red', label=f'{window}-día MA')
plt.fill_between(x, lower, upper, color='red', alpha=0.1, label=f'{window}-día STD')
plt.title('Media móvil y banda de desviación (indicador de tendencia y volatilidad)')
plt.legend()
plt.show()

# Determinar periodo para descomposición: si hay >=252 observaciones probaremos anual, si no usaremos 5 (semanal)
period = 252 if len(df) >= 252 else 5
print(f'Usando periodo={period} para descomposición estacional (si procede)')

# Descomposición estacional (try seasonal_decompose, si falla probar STL)
try:
    res = seasonal_decompose(df['Close'].dropna(), period=period, model='additive', extrapolate_trend='freq')
    fig = res.plot()
    fig.set_size_inches(12,8)
    plt.show()
except Exception as e:
    print('seasonal_decompose falló:', e)
    try:
        stl = STL(df['Close'].dropna(), period=period)
        res2 = stl.fit()
        fig = res2.plot()
        fig.set_size_inches(12,8)
        plt.show()
    except Exception as e2:
        print('STL falló:', e2)

# Test de estacionariedad ADF sobre la serie original y sobre retornos
series = df['Close'].dropna()
print('\n--- Prueba ADF sobre la serie de precios ---')
adf_res = adfuller(series)
print('ADF statistic:', adf_res[0])
print('p-value:', adf_res[1])
print('Valores críticos:', adf_res[4])

# Calcular retornos simples y su estacionariedad
returns = series.pct_change().dropna()
print('\nEstadísticos de retornos (pct_change):')
print(returns.describe())

print('\n--- Prueba ADF sobre retornos ---')
adf_ret = adfuller(returns)
print('ADF statistic (returns):', adf_ret[0])
print('p-value (returns):', adf_ret[1])
print('Valores críticos (returns):', adf_ret[4])

# ACF / PACF para la serie y para retornos
plt.figure(figsize=(12,4))
plot_acf(series, lags=40)
plt.title('ACF - precios de cierre')
plt.show()

plt.figure(figsize=(12,4))
plot_pacf(series, lags=40, method='ywm')
plt.title('PACF - precios de cierre')
plt.show()

plt.figure(figsize=(12,4))
plot_acf(returns, lags=40)
plt.title('ACF - retornos')
plt.show()

plt.figure(figsize=(12,4))
plot_pacf(returns, lags=40, method='ywm')
plt.title('PACF - retornos')
plt.show()

# Guardar resultados básicos para la conclusión posterior
eda_summary = {
    'n_obs': int(len(df)),
    'start': str(df.index.min()),
    'end': str(df.index.max()),
    'n_nulls': int(df['Close'].isna().sum()),
    'adf_pvalue_series': float(adf_res[1]),
    'adf_pvalue_returns': float(adf_ret[1])
}
print('\nEDA summary:', eda_summary)
# Out:
# Observaciones totales (incluyendo nulos): 1221
# Rango de fechas:  2015-01-02 00:00:00 a 2019-12-30 00:00:00
#
# Valores nulos por columna:
# Price  Ticker
# Close  YPFD.BA    0
# dtype: int64
#
# Estadísticos descriptivos de Close:
# Ticker      YPFD.BA
# count   1221.000000
# mean     410.624734
# std      152.916418
# min      173.544662
# 25%      285.039856
# 50%      362.071167
# 75%      523.137756
# max      873.750000
# Usando periodo=252 para descomposición estacional (si procede)
# --- Prueba ADF sobre la serie de precios ---
# ADF statistic: 0.26062849762321105
# p-value: 0.9754642607372288
# Valores críticos: {'1%': np.float64(-3.435806562661181), '5%': np.float64(-2.8639495363486884), '10%': np.float64(-2.56805288000355)}
#
# Estadísticos de retornos (pct_change):
# Ticker      YPFD.BA
# count   1220.000000
# mean       0.001184
# std        0.026421
# min       -0.169145
# 25%       -0.014251
# 50%        0.000000
# 75%        0.015337
# max        0.118462
#
# --- Prueba ADF sobre retornos ---
# ADF statistic (returns): -34.641687918202614
# p-value (returns): 0.0
# Valores críticos (returns): {'1%': np.float64(-3.4357258193266365), '5%': np.float64(-2.863913913276725), '10%': np.float64(-2.5680339084067483)}
# EDA summary: {'n_obs': 1221, 'start': '2015-01-02 00:00:00', 'end': '2019-12-30 00:00:00', 'n_nulls': 0, 'adf_pvalue_series': 0.9754642607372288, 'adf_pvalue_returns': 0.0}
# /tmp/ipython-input-83388592.py:133: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   'n_nulls': int(df['Close'].isna().sum()),

# %%
# Cálculo numérico rápido: ADF y estadísticas clave (sin gráficos)
from statsmodels.tsa.stattools import adfuller
import numpy as np

# Recolectar la serie de cierre y asegurar 1D Series
if 'ypf_data' in globals():
    series = ypf_data['Close'].dropna()
    # si devuelve DataFrame con una sola columna, convertir a Series
    if isinstance(series, (pd.DataFrame,)):
        series = series.iloc[:, 0]
    series = series.astype(float)
else:
    raise RuntimeError('No se encontró `ypf_data`. Ejecutar la celda de descarga primero.')

n_obs = len(series)
start = series.index.min()
end = series.index.max()
n_nulls = int(series.isna().sum())

# Estadísticos básicos
desc = series.describe()

# ADF test on levels
adf_levels = adfuller(series)
adf_levels_stat = float(adf_levels[0])
adf_levels_p = float(adf_levels[1])

# ADF on returns
returns = series.pct_change().dropna()
adf_ret = adfuller(returns)
adf_ret_stat = float(adf_ret[0])
adf_ret_p = float(adf_ret[1])

# Autocorrelaciones de retornos primeras 5 lags
autocorrs = [returns.autocorr(lag=i) for i in range(1,6)]

print('Resumen numérico EDA:')
print('Observaciones:', n_obs)
print('Rango de fechas:', start, 'a', end)
print('Valores nulos en Close:', n_nulls)
print('\nEstadísticos Close:')
print(desc)
print('\nADF (niveles) statistic =', adf_levels_stat, ', p-value =', adf_levels_p)
print('ADF (retornos) statistic =', adf_ret_stat, ', p-value =', adf_ret_p)
print('\nAutocorrelaciones retornos (lags 1..5):', np.round(autocorrs, 4))

# Guardar resultados simples
eda_numeric_summary = {
    'n_obs': int(n_obs),
    'start': str(start),
    'end': str(end),
    'n_nulls': int(n_nulls),
    'adf_levels_p': adf_levels_p,
    'adf_returns_p': adf_ret_p,
    'returns_autocorr_lag1': float(autocorrs[0])
}

print('\nEDA numeric summary saved to `eda_numeric_summary`')
# Out:
# Resumen numérico EDA:
# Observaciones: 1221
# Rango de fechas: 2015-01-02 00:00:00 a 2019-12-30 00:00:00
# Valores nulos en Close: 0
#
# Estadísticos Close:
# count    1221.000000
# mean      410.624734
# std       152.916418
# min       173.544662
# 25%       285.039856
# 50%       362.071167
# 75%       523.137756
# max       873.750000
# Name: YPFD.BA, dtype: float64
#
# ADF (niveles) statistic = 0.26062849762321105 , p-value = 0.9754642607372288
# ADF (retornos) statistic = -34.641687918202614 , p-value = 0.0
#
# Autocorrelaciones retornos (lags 1..5): [0.0098 0.0024 0.0315 0.0281 0.0342]
#
# EDA numeric summary saved to `eda_numeric_summary`

# %% [markdown]
# ## Construcción de una línea de base
#
# La generación de una línea de base es un buen primer paso para resolver muchos problemas que requieren trabajar con datos. Una línea de base es cualquier modelo simple que podemos construir con muy poco tiempo/trabajo, y que usualmente no requiere de la utilización de modelos de aprendizaje automático. Por ejemplo, una línea de base extremadamente simple para cualquier problema es devolver un valor aleatorio. Para el problema que trabajeremos en este práctico, podemos pensar alguna línea de base que nos permita principalmente establecer una cota inferior del rendimiento esperado del modelo. Dicho con otras palabras, si un modelo no es capaz de superar el rendimiento de una mera función en Python que implemente una estrategia o predicción simple, entonces podríamos pensar que nuestro modelo de aprendizaje automático no ha tenido éxito.
#
# Proponga una línea de base determinada y analice el resultado obtenido para un período de tiempo en concreto. Asuma que la información disponible estará determinada por todo dato que se encuentre disponible al momento de la apertura de mercado en el día que se intenta predecir. A modo de ejemplo, un dato que no podría utilizarse para predecir el valor del precio de cierre del día 10 de diciembre de 2025 es el volumen, dado que representa la cantidad de operaciones realizadas a lo largo de todo el día.

# %% [markdown]
# ### Línea de base: predicción ingenua
#
# Se implementa una línea de base que predice el precio de cierre de hoy usando el precio de cierre de ayer (naive forecast). Esta estrategia es común en series temporales financieras y sirve como referencia mínima: cualquier modelo más complejo debería superar este desempeño. Se reporta el error porcentual medio absoluto (MAPE) y se grafican los valores reales vs. predichos.

# %%
# Línea de base: predicción ingenua (naive forecast)
def baseline(df_prices):
    """
    Predice el precio de cierre de hoy usando el precio de cierre de ayer (naive forecast).
    Devuelve el MAPE y un DataFrame con reales y predichos.
    """
    series = df_prices['Close'].dropna()
    y_true = series[1:].to_numpy().ravel()  # desde el segundo día
    y_pred = series[:-1].to_numpy().ravel()  # hasta el penúltimo día
    fechas = series.index[1:]
    fechas = pd.to_datetime(fechas).to_numpy()
    mape = mean_absolute_percentage_error(y_true, y_pred)
    resultados = pd.DataFrame({'Fecha': fechas, 'Real': y_true, 'Predicción': y_pred})
    return mape, resultados

# %%
# Evaluar baseline sobre todo el período disponible
def run_and_plot_baseline():
    mape, resultados = baseline(ypf_data)
    print(f"MAPE baseline (naive forecast): {mape:.4f}")
    # Graficar reales vs predicción
    plt.figure(figsize=(12,4))
    plt.plot(resultados['Fecha'], resultados['Real'], label='Real')
    plt.plot(resultados['Fecha'], resultados['Predicción'], label='Predicción (naive)', alpha=0.7)
    plt.title('Línea de base: predicción ingenua')
    plt.xlabel('Fecha')
    plt.ylabel('Precio de cierre')
    plt.legend()
    plt.grid(True)
    plt.show()
    return mape, resultados

# Ejecutar baseline y mostrar resultados
baseline_mape, baseline_resultados = run_and_plot_baseline()
# Out:
# MAPE baseline (naive forecast): 0.0196

# %% [markdown]
# # Análisis de pesos de una red recurrente simple
#
# Cree una arquitectura de red neuronal recurrente tradicional utilizando para cada ejemplo de entrenamiento una secuencia de largo 40 y 25 unidades, y una única neurona de salida. Sin entrenar dicho modelo, evalúe la estructura de los pesos de dicha red (utilice como ayuda los métodos get_weights y summary). A qué corresponde cada dimensión de la estructura de pesos devuelta?

# %%
# Define a function to create the RNN model
from tensorflow.keras import Input

def create_rnn_model(units, input_shape, layer_class):
    """
    Crea una red recurrente simple seguida de una capa densa de salida.
    - units: número de unidades en la capa recurrente
    - input_shape: (sequence_length, n_features)
    - layer_class: clase recurrente a usar (SimpleRNN, GRU, LSTM)
    """
    model = Sequential()
    # Capa recurrente: no devolver secuencias (return_sequences=False)
    model.add(layer_class(units, input_shape=input_shape, return_sequences=False))
    # Salida: una neurona (regresión del precio)
    model.add(Dense(1, name='output'))

    loss_function = 'mse'
    model.compile(optimizer='adam', loss=loss_function)
    return model

# %%
# Construir un modelo RNN sin entrenar y examinar la estructura de pesos
seq_len = 40
units = 25

# Crear el modelo (se asume entrada univariante -> n_features=1)
model_rnn = create_rnn_model(units, (seq_len, 1), SimpleRNN)

print('\n--- Modelo RNN (sin entrenar) ---')
model_rnn.summary()

# Mostrar pesos por capa y sus shapes
print('\n--- Pesos por capa (get_weights) ---')
for layer in model_rnn.layers:
    w = layer.get_weights()
    print(f"Capa: {layer.name} - tipo: {layer.__class__.__name__}")
    if not w:
        print('  No tiene pesos (p. ej. una capa de activación sin parámetros).')
        continue
    for i, arr in enumerate(w):
        print(f"  peso[{i}] shape = {arr.shape}")

# Interpretación de las formas (explicación):
print('\n--- Interpretación de las matrices de pesos ---')
print('Para la capa SimpleRNN (primera capa) Keras mantiene 3 matrices:')
print('  1) kernel: forma (input_dim, units) -> pesos que conectan la entrada a las unidades recurrentes')
print('  2) recurrent_kernel: forma (units, units) -> pesos de la conexión recurrente entre unidades')
print('  3) bias: forma (units,) -> sesgos para cada unidad')
print(f"  En nuestro caso, input_dim=1, units={units} => kernel (1,{units}), recurrent_kernel ({units},{units}), bias ({units},)")
print('\nPara la capa Dense(1) final Keras mantiene:')
print('  1) kernel: forma (units, 1) -> conecta las unidades recurrentes a la salida')
print('  2) bias: forma (1,) -> sesgo de la salida')
print(f"  En nuestro caso: kernel ({units},1), bias (1,)")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# --- Modelo RNN (sin entrenar) ---
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 25)             │           675 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 701 (2.74 KB)
#  Trainable params: 701 (2.74 KB)
#  Non-trainable params: 0 (0.00 B)
# --- Pesos por capa (get_weights) ---
# Capa: simple_rnn - tipo: SimpleRNN
#   peso[0] shape = (1, 25)
#   peso[1] shape = (25, 25)
#   peso[2] shape = (25,)
# Capa: output - tipo: Dense
#   peso[0] shape = (25, 1)
#   peso[1] shape = (1,)
#
# --- Interpretación de las matrices de pesos ---
# Para la capa SimpleRNN (primera capa) Keras mantiene 3 matrices:
#   1) kernel: forma (input_dim, units) -> pesos que conectan la entrada a las unidades recurrentes
#   2) recurrent_kernel: forma (units, units) -> pesos de la conexión recurrente entre unidades
#   3) bias: forma (units,) -> sesgos para cada unidad
#   En nuestro caso, input_dim=1, units=25 => kernel (1,25), recurrent_kernel (25,25), bias (25,)
#
# Para la capa Dense(1) final Keras mantiene:
#   1) kernel: forma (units, 1) -> conecta las unidades recurrentes a la salida
#   2) bias: forma (1,) -> sesgo de la salida
#   En nuestro caso: kernel (25,1), bias (1,)

# %% [markdown]
# # Experimentación
#
# Proponga y analice distintas arquitecturas de redes neuronales recurrentes (simple, GRU y LSTM) variando la cantidad de unidades en cada caso y el largo de las secuencias de entrenamiento. Proponga un valor razonable para los hiper-parámetros de épocas de entrenamiento, tamaño del batch y proporción de casos en el conjunto de validación. Seleccione una función de costo y una métrica para evaluar los resultados, ambas acordes a este problema. Evaluar si algunas combinaciones genera sobre-entrenamiento podría ser útil para guiar la búsqueda/selección de hiper-parámetros.
#
# Complete la función "evaluate_model" para que realice el entrenamiento de un modelo dado. Tenga presente que en este problema el modelo nunca debería ver en el conjunto de entrenamiento datos posteriores a los que se analicen en el período de evaluación/test.
#
# Concluya sobre qué modelo obtuvo un mejor desempeño y, en caso de ser posible, analice qué combinación de hiper-parámetros suele dar mejores resultados. Considere en dicho análisis la cantidad de pesos de cada modelo y cómo este aspecto podría ayudar o interferir en el aprendizaje del mismo de acuerdo a la cantidad de datos disponibles en este problema. Analice la cantidad de parámetros de dicho modelo respecto a los analizados en el punto anterior.

# %%
def evaluate_model(model,
                   prices,
                   window_size,
                   epochs=50,
                   batch_size=32,
                   validation_split=0.2):
    """
    Entrena y evalúa un modelo de series temporales sin fuga temporal.
    - `prices`: array-like con shape (n_samples, 1) o pandas Series
    - `window_size`: largo de la secuencia (int)
    - `validation_split`: proporción final de datos usada como validación (por ejemplo 0.2)

    Devuelve: (history, metrics_dict, y_true_vs_pred)
    """
    import numpy as np
    from sklearn.preprocessing import StandardScaler
    from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error, mean_absolute_error

    # Crear secuencias (X shape: (N, window_size, 1), y shape: (N,1))
    X, y = create_sequences(prices, window_size)
    if len(X) == 0:
        raise ValueError('window_size demasiado grande para la serie proporcionada')

    # División temporal: primeros datos -> entrenamiento, últimos -> validación
    split_idx = int(len(X) * (1 - validation_split))
    X_train, X_val = X[:split_idx], X[split_idx:]
    y_train, y_val = y[:split_idx], y[split_idx:]

    # Escalado: ajustar scaler únicamente con los datos de entrenamiento (evitar fuga)
    scaler = StandardScaler()
    X_train_flat = X_train.reshape(-1, 1)
    scaler.fit(X_train_flat)

    X_train_s = scaler.transform(X_train_flat).reshape(X_train.shape)
    X_val_s = scaler.transform(X_val.reshape(-1, 1)).reshape(X_val.shape)
    y_train_s = scaler.transform(y_train.reshape(-1, 1)).reshape(-1, 1)
    y_val_s = scaler.transform(y_val.reshape(-1, 1)).reshape(-1, 1)

    # Entrenamiento (sin shuffle para preservar orden temporal)
    history = model.fit(
        X_train_s, y_train_s,
        validation_data=(X_val_s, y_val_s),
        epochs=epochs,
        batch_size=batch_size,
        shuffle=False,
        verbose=2
    )

    # Predicción y evaluación (devolver a escala original)
    y_pred_s = model.predict(X_val_s)
    y_pred = scaler.inverse_transform(y_pred_s).ravel()
    y_true = y_val.ravel()

    mape = mean_absolute_percentage_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)

    metrics = {
        'mape': float(mape),
        'mse': float(mse),
        'mae': float(mae),
        'n_train': int(len(X_train)),
        'n_val': int(len(X_val)),
        'n_params': int(model.count_params())
    }

    # Empaquetar resultados para inspección posterior
    y_pair = {
        'y_true': y_true,
        'y_pred': y_pred
    }

    return history, metrics, y_pair

# %%
# config item (units, sequence_length, layer_class, epochs, batch_size, validation_split)
configs = [
    (50, 60, SimpleRNN, 100, 32, 0.2),
    (50, 60, GRU, 100, 32, 0.2),
    (50, 60, LSTM, 100, 32, 0.2)
]

for config_item in configs:
    print(f"Evaluando la configuración: {config_item}")
    units, sequence_length, layer_class, epochs, batch_size, validation_split = config_item
    evaluate_model(create_rnn_model(units, (sequence_length, 1), layer_class),
                   close_prices,
                   sequence_length,
                   epochs,
                   batch_size,
                   validation_split)
    print('-' * 50)
# Out:
# Evaluando la configuración: (50, 60, <class 'keras.src.layers.rnn.simple_rnn.SimpleRNN'>, 100, 32, 0.2)
# Epoch 1/100
# 29/29 - 3s - 100ms/step - loss: 0.2028 - val_loss: 4.7024
# Epoch 2/100
# 29/29 - 0s - 8ms/step - loss: 0.0881 - val_loss: 2.2368
# Epoch 3/100
# 29/29 - 0s - 8ms/step - loss: 0.0600 - val_loss: 1.8228
# Epoch 4/100
# 29/29 - 0s - 8ms/step - loss: 0.0399 - val_loss: 1.5442
# Epoch 5/100
# 29/29 - 0s - 8ms/step - loss: 0.0390 - val_loss: 1.3462
# Epoch 6/100
# 29/29 - 0s - 10ms/step - loss: 0.0331 - val_loss: 1.2884
# Epoch 7/100
# 29/29 - 0s - 10ms/step - loss: 0.0230 - val_loss: 1.0788
# Epoch 8/100
# 29/29 - 0s - 10ms/step - loss: 0.0218 - val_loss: 1.0486
# Epoch 9/100
# 29/29 - 0s - 10ms/step - loss: 0.0199 - val_loss: 0.9168
# Epoch 10/100
# 29/29 - 0s - 10ms/step - loss: 0.0190 - val_loss: 0.8439
# Epoch 11/100
# 29/29 - 1s - 22ms/step - loss: 0.0180 - val_loss: 0.7885
# Epoch 12/100
# 29/29 - 0s - 9ms/step - loss: 0.0171 - val_loss: 0.7311
# Epoch 13/100
# 29/29 - 0s - 8ms/step - loss: 0.0165 - val_loss: 0.6760
# Epoch 14/100
# 29/29 - 0s - 9ms/step - loss: 0.0161 - val_loss: 0.6303
# Epoch 15/100
# 29/29 - 0s - 8ms/step - loss: 0.0158 - val_loss: 0.5903
# Epoch 16/100
# 29/29 - 0s - 8ms/step - loss: 0.0155 - val_loss: 0.5524
# Epoch 17/100
# 29/29 - 0s - 8ms/step - loss: 0.0150 - val_loss: 0.5182
# Epoch 18/100
# 29/29 - 0s - 8ms/step - loss: 0.0145 - val_loss: 0.4894
# Epoch 19/100
# 29/29 - 0s - 8ms/step - loss: 0.0141 - val_loss: 0.4651
# Epoch 20/100
# 29/29 - 0s - 8ms/step - loss: 0.0139 - val_loss: 0.4438
# Epoch 21/100
# 29/29 - 0s - 8ms/step - loss: 0.0137 - val_loss: 0.4244
# Epoch 22/100
# 29/29 - 0s - 8ms/step - loss: 0.0137 - val_loss: 0.4060
# Epoch 23/100
# 29/29 - 0s - 8ms/step - loss: 0.0136 - val_loss: 0.3882
# Epoch 24/100
# 29/29 - 0s - 8ms/step - loss: 0.0133 - val_loss: 0.3711
# Epoch 25/100
# 29/29 - 0s - 8ms/step - loss: 0.0128 - val_loss: 0.3559
# Epoch 26/100
# 29/29 - 0s - 8ms/step - loss: 0.0123 - val_loss: 0.3432
# Epoch 27/100
# 29/29 - 0s - 8ms/step - loss: 0.0120 - val_loss: 0.3319
# Epoch 28/100
# 29/29 - 0s - 8ms/step - loss: 0.0119 - val_loss: 0.3217
# Epoch 29/100
# 29/29 - 0s - 8ms/step - loss: 0.0118 - val_loss: 0.3129
# Epoch 30/100
# 29/29 - 0s - 8ms/step - loss: 0.0119 - val_loss: 0.3056
# Epoch 31/100
# 29/29 - 0s - 9ms/step - loss: 0.0120 - val_loss: 0.2992
# Epoch 32/100
# 29/29 - 0s - 8ms/step - loss: 0.0124 - val_loss: 0.2925
# Epoch 33/100
# 29/29 - 0s - 8ms/step - loss: 0.0127 - val_loss: 0.2824
# Epoch 34/100
# 29/29 - 0s - 8ms/step - loss: 0.0119 - val_loss: 0.2705
# Epoch 35/100
# 29/29 - 0s - 8ms/step - loss: 0.0108 - val_loss: 0.2653
# Epoch 36/100
# 29/29 - 0s - 8ms/step - loss: 0.0103 - val_loss: 0.2603
# Epoch 37/100
# 29/29 - 0s - 8ms/step - loss: 0.0103 - val_loss: 0.2511
# Epoch 38/100
# 29/29 - 0s - 8ms/step - loss: 0.0104 - val_loss: 0.2405
# Epoch 39/100
# 29/29 - 0s - 11ms/step - loss: 0.0105 - val_loss: 0.2344
# Epoch 40/100
# 29/29 - 0s - 8ms/step - loss: 0.0109 - val_loss: 0.2339
# Epoch 41/100
# 29/29 - 0s - 8ms/step - loss: 0.0112 - val_loss: 0.2373
# Epoch 42/100
# 29/29 - 0s - 8ms/step - loss: 0.0111 - val_loss: 0.2420
# Epoch 43/100
# 29/29 - 0s - 8ms/step - loss: 0.0110 - val_loss: 0.2445
# Epoch 44/100
# 29/29 - 0s - 8ms/step - loss: 0.0119 - val_loss: 0.2431
# Epoch 45/100
# 29/29 - 0s - 8ms/step - loss: 0.0131 - val_loss: 0.2271
# Epoch 46/100
# 29/29 - 0s - 8ms/step - loss: 0.0109 - val_loss: 0.2156
# Epoch 47/100
# 29/29 - 0s - 8ms/step - loss: 0.0095 - val_loss: 0.2188
# Epoch 48/100
# 29/29 - 0s - 8ms/step - loss: 0.0096 - val_loss: 0.2134
# Epoch 49/100
# 29/29 - 0s - 11ms/step - loss: 0.0097 - val_loss: 0.2027
# Epoch 50/100
# 29/29 - 0s - 8ms/step - loss: 0.0098 - val_loss: 0.1970
# Epoch 51/100
# 29/29 - 0s - 8ms/step - loss: 0.0100 - val_loss: 0.1995
# Epoch 52/100
# 29/29 - 0s - 10ms/step - loss: 0.0103 - val_loss: 0.2060
# Epoch 53/100
# 29/29 - 0s - 11ms/step - loss: 0.0108 - val_loss: 0.2118
# Epoch 54/100
# 29/29 - 1s - 21ms/step - loss: 0.0114 - val_loss: 0.2136
# Epoch 55/100
# 29/29 - 1s - 22ms/step - loss: 0.0110 - val_loss: 0.2094
# Epoch 56/100
# 29/29 - 0s - 9ms/step - loss: 0.0100 - val_loss: 0.2059
# Epoch 57/100
# 29/29 - 0s - 8ms/step - loss: 0.0093 - val_loss: 0.2008
# Epoch 58/100
# 29/29 - 0s - 8ms/step - loss: 0.0092 - val_loss: 0.1961
# Epoch 59/100
# 29/29 - 0s - 9ms/step - loss: 0.0093 - val_loss: 0.1878
# Epoch 60/100
# 29/29 - 0s - 8ms/step - loss: 0.0093 - val_loss: 0.1813
# Epoch 61/100
# 29/29 - 0s - 8ms/step - loss: 0.0094 - val_loss: 0.1800
# Epoch 62/100
# 29/29 - 0s - 8ms/step - loss: 0.0096 - val_loss: 0.1833
# Epoch 63/100
# 29/29 - 0s - 8ms/step - loss: 0.0097 - val_loss: 0.1877
# Epoch 64/100
# 29/29 - 0s - 8ms/step - loss: 0.0100 - val_loss: 0.1904
# Epoch 65/100
# 29/29 - 0s - 8ms/step - loss: 0.0107 - val_loss: 0.1943
# Epoch 66/100
# 29/29 - 0s - 8ms/step - loss: 0.0109 - val_loss: 0.1905
# Epoch 67/100
# 29/29 - 0s - 8ms/step - loss: 0.0099 - val_loss: 0.1814
# Epoch 68/100
# 29/29 - 0s - 8ms/step - loss: 0.0092 - val_loss: 0.1802
# Epoch 69/100
# 29/29 - 0s - 10ms/step - loss: 0.0091 - val_loss: 0.1731
# Epoch 70/100
# 29/29 - 0s - 8ms/step - loss: 0.0092 - val_loss: 0.1673
# Epoch 71/100
# 29/29 - 0s - 8ms/step - loss: 0.0094 - val_loss: 0.1668
# Epoch 72/100
# 29/29 - 0s - 8ms/step - loss: 0.0096 - val_loss: 0.1692
# Epoch 73/100
# 29/29 - 0s - 8ms/step - loss: 0.0095 - val_loss: 0.1750
# Epoch 74/100
# 29/29 - 0s - 8ms/step - loss: 0.0099 - val_loss: 0.1813
# Epoch 75/100
# 29/29 - 0s - 8ms/step - loss: 0.0111 - val_loss: 0.1799
# Epoch 76/100
# 29/29 - 0s - 8ms/step - loss: 0.0116 - val_loss: 0.1825
# Epoch 77/100
# 29/29 - 0s - 8ms/step - loss: 0.0101 - val_loss: 0.1793
# Epoch 78/100
# 29/29 - 0s - 8ms/step - loss: 0.0091 - val_loss: 0.1764
# Epoch 79/100
# 29/29 - 0s - 9ms/step - loss: 0.0089 - val_loss: 0.1724
# Epoch 80/100
# 29/29 - 0s - 8ms/step - loss: 0.0089 - val_loss: 0.1643
# Epoch 81/100
# 29/29 - 0s - 8ms/step - loss: 0.0092 - val_loss: 0.1591
# Epoch 82/100
# 29/29 - 0s - 8ms/step - loss: 0.0095 - val_loss: 0.1593
# Epoch 83/100
# 29/29 - 0s - 8ms/step - loss: 0.0096 - val_loss: 0.1663
# Epoch 84/100
# 29/29 - 0s - 10ms/step - loss: 0.0093 - val_loss: 0.1721
# Epoch 85/100
# 29/29 - 0s - 8ms/step - loss: 0.0098 - val_loss: 0.1765
# Epoch 86/100
# 29/29 - 0s - 8ms/step - loss: 0.0113 - val_loss: 0.1744
# Epoch 87/100
# 29/29 - 0s - 8ms/step - loss: 0.0108 - val_loss: 0.1589
# Epoch 88/100
# 29/29 - 0s - 8ms/step - loss: 0.0096 - val_loss: 0.1695
# Epoch 89/100
# 29/29 - 0s - 8ms/step - loss: 0.0090 - val_loss: 0.1728
# Epoch 90/100
# 29/29 - 0s - 8ms/step - loss: 0.0089 - val_loss: 0.1664
# Epoch 91/100
# 29/29 - 0s - 9ms/step - loss: 0.0090 - val_loss: 0.1666
# Epoch 92/100
# 29/29 - 0s - 8ms/step - loss: 0.0092 - val_loss: 0.1689
# Epoch 93/100
# 29/29 - 0s - 8ms/step - loss: 0.0096 - val_loss: 0.1699
# Epoch 94/100
# 29/29 - 0s - 8ms/step - loss: 0.0104 - val_loss: 0.1682
# Epoch 95/100
# 29/29 - 0s - 9ms/step - loss: 0.0115 - val_loss: 0.1646
# Epoch 96/100
# 29/29 - 0s - 8ms/step - loss: 0.0112 - val_loss: 0.1784
# Epoch 97/100
# 29/29 - 0s - 10ms/step - loss: 0.0098 - val_loss: 0.1707
# Epoch 98/100
# 29/29 - 1s - 22ms/step - loss: 0.0092 - val_loss: 0.1645
# Epoch 99/100
# 29/29 - 0s - 11ms/step - loss: 0.0091 - val_loss: 0.1579
# Epoch 100/100
# 29/29 - 0s - 11ms/step - loss: 0.0093 - val_loss: 0.1493
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step
# --------------------------------------------------
# Evaluando la configuración: (50, 60, <class 'keras.src.layers.rnn.gru.GRU'>, 100, 32, 0.2)
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 29/29 - 3s - 89ms/step - loss: 0.6471 - val_loss: 3.2102
# Epoch 2/100
# 29/29 - 0s - 8ms/step - loss: 0.0457 - val_loss: 0.6452
# Epoch 3/100
# 29/29 - 0s - 8ms/step - loss: 0.0325 - val_loss: 0.6416
# Epoch 4/100
# 29/29 - 0s - 7ms/step - loss: 0.0318 - val_loss: 0.5499
# Epoch 5/100
# 29/29 - 0s - 8ms/step - loss: 0.0275 - val_loss: 0.4689
# Epoch 6/100
# 29/29 - 0s - 7ms/step - loss: 0.0265 - val_loss: 0.4458
# Epoch 7/100
# 29/29 - 0s - 7ms/step - loss: 0.0245 - val_loss: 0.3804
# Epoch 8/100
# 29/29 - 0s - 7ms/step - loss: 0.0233 - val_loss: 0.3666
# Epoch 9/100
# 29/29 - 0s - 8ms/step - loss: 0.0224 - val_loss: 0.3284
# Epoch 10/100
# 29/29 - 0s - 7ms/step - loss: 0.0214 - val_loss: 0.3069
# Epoch 11/100
# 29/29 - 0s - 7ms/step - loss: 0.0208 - val_loss: 0.2882
# Epoch 12/100
# 29/29 - 0s - 7ms/step - loss: 0.0200 - val_loss: 0.2622
# Epoch 13/100
# 29/29 - 0s - 9ms/step - loss: 0.0195 - val_loss: 0.2515
# Epoch 14/100
# 29/29 - 0s - 8ms/step - loss: 0.0188 - val_loss: 0.2293
# Epoch 15/100
# 29/29 - 0s - 10ms/step - loss: 0.0182 - val_loss: 0.2178
# Epoch 16/100
# 29/29 - 0s - 7ms/step - loss: 0.0178 - val_loss: 0.2031
# Epoch 17/100
# 29/29 - 0s - 7ms/step - loss: 0.0172 - val_loss: 0.1896
# Epoch 18/100
# 29/29 - 0s - 7ms/step - loss: 0.0169 - val_loss: 0.1801
# Epoch 19/100
# 29/29 - 0s - 7ms/step - loss: 0.0164 - val_loss: 0.1678
# Epoch 20/100
# 29/29 - 0s - 7ms/step - loss: 0.0161 - val_loss: 0.1599
# Epoch 21/100
# 29/29 - 0s - 7ms/step - loss: 0.0157 - val_loss: 0.1508
# Epoch 22/100
# 29/29 - 0s - 7ms/step - loss: 0.0154 - val_loss: 0.1436
# Epoch 23/100
# 29/29 - 0s - 7ms/step - loss: 0.0151 - val_loss: 0.1371
# Epoch 24/100
# 29/29 - 0s - 7ms/step - loss: 0.0149 - val_loss: 0.1311
# Epoch 25/100
# 29/29 - 0s - 7ms/step - loss: 0.0146 - val_loss: 0.1262
# Epoch 26/100
# 29/29 - 0s - 7ms/step - loss: 0.0144 - val_loss: 0.1216
# Epoch 27/100
# 29/29 - 0s - 7ms/step - loss: 0.0142 - val_loss: 0.1177
# Epoch 28/100
# 29/29 - 0s - 7ms/step - loss: 0.0140 - val_loss: 0.1143
# Epoch 29/100
# 29/29 - 0s - 8ms/step - loss: 0.0138 - val_loss: 0.1113
# Epoch 30/100
# 29/29 - 0s - 8ms/step - loss: 0.0136 - val_loss: 0.1087
# Epoch 31/100
# 29/29 - 0s - 7ms/step - loss: 0.0135 - val_loss: 0.1064
# Epoch 32/100
# 29/29 - 0s - 10ms/step - loss: 0.0133 - val_loss: 0.1044
# Epoch 33/100
# 29/29 - 0s - 10ms/step - loss: 0.0132 - val_loss: 0.1027
# Epoch 34/100
# 29/29 - 0s - 10ms/step - loss: 0.0131 - val_loss: 0.1011
# Epoch 35/100
# 29/29 - 0s - 10ms/step - loss: 0.0129 - val_loss: 0.0998
# Epoch 36/100
# 29/29 - 0s - 14ms/step - loss: 0.0128 - val_loss: 0.0985
# Epoch 37/100
# 29/29 - 0s - 11ms/step - loss: 0.0127 - val_loss: 0.0975
# Epoch 38/100
# 29/29 - 1s - 18ms/step - loss: 0.0126 - val_loss: 0.0965
# Epoch 39/100
# 29/29 - 0s - 7ms/step - loss: 0.0125 - val_loss: 0.0957
# Epoch 40/100
# 29/29 - 0s - 7ms/step - loss: 0.0124 - val_loss: 0.0949
# Epoch 41/100
# 29/29 - 0s - 7ms/step - loss: 0.0123 - val_loss: 0.0942
# Epoch 42/100
# 29/29 - 0s - 7ms/step - loss: 0.0122 - val_loss: 0.0936
# Epoch 43/100
# 29/29 - 0s - 7ms/step - loss: 0.0121 - val_loss: 0.0930
# Epoch 44/100
# 29/29 - 0s - 7ms/step - loss: 0.0120 - val_loss: 0.0925
# Epoch 45/100
# 29/29 - 0s - 7ms/step - loss: 0.0119 - val_loss: 0.0920
# Epoch 46/100
# 29/29 - 0s - 7ms/step - loss: 0.0118 - val_loss: 0.0916
# Epoch 47/100
# 29/29 - 0s - 7ms/step - loss: 0.0118 - val_loss: 0.0911
# Epoch 48/100
# 29/29 - 0s - 7ms/step - loss: 0.0117 - val_loss: 0.0907
# Epoch 49/100
# 29/29 - 0s - 7ms/step - loss: 0.0116 - val_loss: 0.0904
# Epoch 50/100
# 29/29 - 0s - 7ms/step - loss: 0.0116 - val_loss: 0.0900
# Epoch 51/100
# 29/29 - 0s - 7ms/step - loss: 0.0115 - val_loss: 0.0897
# Epoch 52/100
# 29/29 - 0s - 7ms/step - loss: 0.0114 - val_loss: 0.0893
# Epoch 53/100
# 29/29 - 0s - 7ms/step - loss: 0.0114 - val_loss: 0.0890
# Epoch 54/100
# 29/29 - 0s - 7ms/step - loss: 0.0113 - val_loss: 0.0887
# Epoch 55/100
# 29/29 - 0s - 7ms/step - loss: 0.0113 - val_loss: 0.0884
# Epoch 56/100
# 29/29 - 0s - 7ms/step - loss: 0.0112 - val_loss: 0.0881
# Epoch 57/100
# 29/29 - 0s - 7ms/step - loss: 0.0112 - val_loss: 0.0878
# Epoch 58/100
# 29/29 - 0s - 7ms/step - loss: 0.0111 - val_loss: 0.0875
# Epoch 59/100
# 29/29 - 0s - 7ms/step - loss: 0.0111 - val_loss: 0.0872
# Epoch 60/100
# 29/29 - 0s - 7ms/step - loss: 0.0110 - val_loss: 0.0869
# Epoch 61/100
# 29/29 - 0s - 7ms/step - loss: 0.0110 - val_loss: 0.0866
# Epoch 62/100
# 29/29 - 0s - 7ms/step - loss: 0.0110 - val_loss: 0.0863
# Epoch 63/100
# 29/29 - 0s - 7ms/step - loss: 0.0109 - val_loss: 0.0860
# Epoch 64/100
# 29/29 - 0s - 7ms/step - loss: 0.0109 - val_loss: 0.0857
# Epoch 65/100
# 29/29 - 0s - 8ms/step - loss: 0.0109 - val_loss: 0.0854
# Epoch 66/100
# 29/29 - 0s - 7ms/step - loss: 0.0108 - val_loss: 0.0851
# Epoch 67/100
# 29/29 - 0s - 7ms/step - loss: 0.0108 - val_loss: 0.0848
# Epoch 68/100
# 29/29 - 0s - 7ms/step - loss: 0.0108 - val_loss: 0.0845
# Epoch 69/100
# 29/29 - 0s - 7ms/step - loss: 0.0108 - val_loss: 0.0842
# Epoch 70/100
# 29/29 - 0s - 7ms/step - loss: 0.0108 - val_loss: 0.0838
# Epoch 71/100
# 29/29 - 0s - 8ms/step - loss: 0.0107 - val_loss: 0.0835
# Epoch 72/100
# 29/29 - 0s - 7ms/step - loss: 0.0107 - val_loss: 0.0832
# Epoch 73/100
# 29/29 - 0s - 7ms/step - loss: 0.0107 - val_loss: 0.0828
# Epoch 74/100
# 29/29 - 0s - 7ms/step - loss: 0.0107 - val_loss: 0.0825
# Epoch 75/100
# 29/29 - 0s - 7ms/step - loss: 0.0107 - val_loss: 0.0821
# Epoch 76/100
# 29/29 - 0s - 8ms/step - loss: 0.0106 - val_loss: 0.0818
# Epoch 77/100
# 29/29 - 0s - 7ms/step - loss: 0.0106 - val_loss: 0.0814
# Epoch 78/100
# 29/29 - 0s - 7ms/step - loss: 0.0106 - val_loss: 0.0811
# Epoch 79/100
# 29/29 - 0s - 7ms/step - loss: 0.0106 - val_loss: 0.0807
# Epoch 80/100
# 29/29 - 0s - 7ms/step - loss: 0.0105 - val_loss: 0.0803
# Epoch 81/100
# 29/29 - 0s - 7ms/step - loss: 0.0105 - val_loss: 0.0800
# Epoch 82/100
# 29/29 - 0s - 7ms/step - loss: 0.0105 - val_loss: 0.0797
# Epoch 83/100
# 29/29 - 0s - 7ms/step - loss: 0.0105 - val_loss: 0.0794
# Epoch 84/100
# 29/29 - 0s - 11ms/step - loss: 0.0105 - val_loss: 0.0790
# Epoch 85/100
# 29/29 - 0s - 10ms/step - loss: 0.0104 - val_loss: 0.0787
# Epoch 86/100
# 29/29 - 0s - 10ms/step - loss: 0.0104 - val_loss: 0.0785
# Epoch 87/100
# 29/29 - 0s - 11ms/step - loss: 0.0104 - val_loss: 0.0782
# Epoch 88/100
# 29/29 - 0s - 10ms/step - loss: 0.0104 - val_loss: 0.0779
# Epoch 89/100
# 29/29 - 0s - 10ms/step - loss: 0.0104 - val_loss: 0.0776
# Epoch 90/100
# 29/29 - 0s - 10ms/step - loss: 0.0104 - val_loss: 0.0774
# Epoch 91/100
# 29/29 - 0s - 7ms/step - loss: 0.0104 - val_loss: 0.0771
# Epoch 92/100
# 29/29 - 0s - 7ms/step - loss: 0.0103 - val_loss: 0.0769
# Epoch 93/100
# 29/29 - 0s - 7ms/step - loss: 0.0103 - val_loss: 0.0767
# Epoch 94/100
# 29/29 - 0s - 7ms/step - loss: 0.0103 - val_loss: 0.0764
# Epoch 95/100
# 29/29 - 0s - 7ms/step - loss: 0.0103 - val_loss: 0.0762
# Epoch 96/100
# 29/29 - 0s - 7ms/step - loss: 0.0103 - val_loss: 0.0760
# Epoch 97/100
# 29/29 - 0s - 7ms/step - loss: 0.0103 - val_loss: 0.0758
# Epoch 98/100
# 29/29 - 0s - 7ms/step - loss: 0.0103 - val_loss: 0.0756
# Epoch 99/100
# 29/29 - 0s - 7ms/step - loss: 0.0103 - val_loss: 0.0754
# Epoch 100/100
# 29/29 - 0s - 8ms/step - loss: 0.0103 - val_loss: 0.0752
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# --------------------------------------------------
# Evaluando la configuración: (50, 60, <class 'keras.src.layers.rnn.lstm.LSTM'>, 100, 32, 0.2)
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 29/29 - 1s - 44ms/step - loss: 0.5204 - val_loss: 4.6841
# Epoch 2/100
# 29/29 - 0s - 8ms/step - loss: 0.0927 - val_loss: 1.7136
# Epoch 3/100
# 29/29 - 0s - 8ms/step - loss: 0.0856 - val_loss: 1.1522
# Epoch 4/100
# 29/29 - 0s - 7ms/step - loss: 0.0506 - val_loss: 0.9453
# Epoch 5/100
# 29/29 - 0s - 7ms/step - loss: 0.0471 - val_loss: 0.8034
# Epoch 6/100
# 29/29 - 0s - 7ms/step - loss: 0.0442 - val_loss: 0.6829
# Epoch 7/100
# 29/29 - 0s - 7ms/step - loss: 0.0393 - val_loss: 0.6065
# Epoch 8/100
# 29/29 - 0s - 7ms/step - loss: 0.0387 - val_loss: 0.5501
# Epoch 9/100
# 29/29 - 0s - 7ms/step - loss: 0.0354 - val_loss: 0.4797
# Epoch 10/100
# 29/29 - 0s - 7ms/step - loss: 0.0347 - val_loss: 0.4470
# Epoch 11/100
# 29/29 - 0s - 7ms/step - loss: 0.0331 - val_loss: 0.3918
# Epoch 12/100
# 29/29 - 0s - 7ms/step - loss: 0.0308 - val_loss: 0.3543
# Epoch 13/100
# 29/29 - 0s - 8ms/step - loss: 0.0308 - val_loss: 0.3391
# Epoch 14/100
# 29/29 - 0s - 8ms/step - loss: 0.0285 - val_loss: 0.2879
# Epoch 15/100
# 29/29 - 0s - 8ms/step - loss: 0.0278 - val_loss: 0.2823
# Epoch 16/100
# 29/29 - 0s - 7ms/step - loss: 0.0271 - val_loss: 0.2538
# Epoch 17/100
# 29/29 - 0s - 7ms/step - loss: 0.0252 - val_loss: 0.2257
# Epoch 18/100
# 29/29 - 0s - 7ms/step - loss: 0.0254 - val_loss: 0.2290
# Epoch 19/100
# 29/29 - 0s - 7ms/step - loss: 0.0241 - val_loss: 0.1969
# Epoch 20/100
# 29/29 - 0s - 8ms/step - loss: 0.0231 - val_loss: 0.1857
# Epoch 21/100
# 29/29 - 0s - 7ms/step - loss: 0.0230 - val_loss: 0.1839
# Epoch 22/100
# 29/29 - 0s - 7ms/step - loss: 0.0223 - val_loss: 0.1667
# Epoch 23/100
# 29/29 - 0s - 7ms/step - loss: 0.0216 - val_loss: 0.1541
# Epoch 24/100
# 29/29 - 0s - 8ms/step - loss: 0.0212 - val_loss: 0.1524
# Epoch 25/100
# 29/29 - 0s - 7ms/step - loss: 0.0211 - val_loss: 0.1455
# Epoch 26/100
# 29/29 - 0s - 7ms/step - loss: 0.0204 - val_loss: 0.1336
# Epoch 27/100
# 29/29 - 0s - 8ms/step - loss: 0.0198 - val_loss: 0.1279
# Epoch 28/100
# 29/29 - 0s - 7ms/step - loss: 0.0197 - val_loss: 0.1269
# Epoch 29/100
# 29/29 - 0s - 7ms/step - loss: 0.0199 - val_loss: 0.1206
# Epoch 30/100
# 29/29 - 0s - 7ms/step - loss: 0.0189 - val_loss: 0.1126
# Epoch 31/100
# 29/29 - 0s - 11ms/step - loss: 0.0186 - val_loss: 0.1100
# Epoch 32/100
# 29/29 - 0s - 10ms/step - loss: 0.0186 - val_loss: 0.1088
# Epoch 33/100
# 29/29 - 0s - 10ms/step - loss: 0.0200 - val_loss: 0.1084
# Epoch 34/100
# 29/29 - 0s - 11ms/step - loss: 0.0179 - val_loss: 0.0993
# Epoch 35/100
# 29/29 - 0s - 11ms/step - loss: 0.0209 - val_loss: 0.0936
# Epoch 36/100
# 29/29 - 0s - 11ms/step - loss: 0.0201 - val_loss: 0.1263
# Epoch 37/100
# 29/29 - 0s - 9ms/step - loss: 0.0168 - val_loss: 0.0962
# Epoch 38/100
# 29/29 - 0s - 8ms/step - loss: 0.0181 - val_loss: 0.0917
# Epoch 39/100
# 29/29 - 0s - 8ms/step - loss: 0.0165 - val_loss: 0.1076
# Epoch 40/100
# 29/29 - 0s - 7ms/step - loss: 0.0165 - val_loss: 0.1009
# Epoch 41/100
# 29/29 - 0s - 7ms/step - loss: 0.0155 - val_loss: 0.0919
# Epoch 42/100
# 29/29 - 0s - 7ms/step - loss: 0.0164 - val_loss: 0.0943
# Epoch 43/100
# 29/29 - 0s - 7ms/step - loss: 0.0172 - val_loss: 0.0919
# Epoch 44/100
# 29/29 - 0s - 7ms/step - loss: 0.0155 - val_loss: 0.0866
# Epoch 45/100
# 29/29 - 0s - 7ms/step - loss: 0.0153 - val_loss: 0.0864
# Epoch 46/100
# 29/29 - 0s - 7ms/step - loss: 0.0144 - val_loss: 0.0878
# Epoch 47/100
# 29/29 - 0s - 7ms/step - loss: 0.0158 - val_loss: 0.0905
# Epoch 48/100
# 29/29 - 0s - 7ms/step - loss: 0.0180 - val_loss: 0.0887
# Epoch 49/100
# 29/29 - 0s - 8ms/step - loss: 0.0150 - val_loss: 0.0866
# Epoch 50/100
# 29/29 - 0s - 7ms/step - loss: 0.0186 - val_loss: 0.0878
# Epoch 51/100
# 29/29 - 0s - 8ms/step - loss: 0.0151 - val_loss: 0.0794
# Epoch 52/100
# 29/29 - 0s - 8ms/step - loss: 0.0179 - val_loss: 0.0757
# Epoch 53/100
# 29/29 - 0s - 8ms/step - loss: 0.0151 - val_loss: 0.1049
# Epoch 54/100
# 29/29 - 0s - 7ms/step - loss: 0.0142 - val_loss: 0.0908
# Epoch 55/100
# 29/29 - 0s - 8ms/step - loss: 0.0139 - val_loss: 0.0799
# Epoch 56/100
# 29/29 - 0s - 7ms/step - loss: 0.0137 - val_loss: 0.0884
# Epoch 57/100
# 29/29 - 0s - 7ms/step - loss: 0.0136 - val_loss: 0.0838
# Epoch 58/100
# 29/29 - 0s - 7ms/step - loss: 0.0131 - val_loss: 0.0810
# Epoch 59/100
# 29/29 - 0s - 7ms/step - loss: 0.0125 - val_loss: 0.0828
# Epoch 60/100
# 29/29 - 0s - 7ms/step - loss: 0.0135 - val_loss: 0.0847
# Epoch 61/100
# 29/29 - 0s - 7ms/step - loss: 0.0167 - val_loss: 0.0837
# Epoch 62/100
# 29/29 - 0s - 7ms/step - loss: 0.0132 - val_loss: 0.0838
# Epoch 63/100
# 29/29 - 0s - 8ms/step - loss: 0.0151 - val_loss: 0.0802
# Epoch 64/100
# 29/29 - 0s - 8ms/step - loss: 0.0148 - val_loss: 0.0848
# Epoch 65/100
# 29/29 - 0s - 7ms/step - loss: 0.0152 - val_loss: 0.0665
# Epoch 66/100
# 29/29 - 0s - 7ms/step - loss: 0.0131 - val_loss: 0.0798
# Epoch 67/100
# 29/29 - 0s - 8ms/step - loss: 0.0131 - val_loss: 0.0885
# Epoch 68/100
# 29/29 - 0s - 7ms/step - loss: 0.0124 - val_loss: 0.0808
# Epoch 69/100
# 29/29 - 0s - 7ms/step - loss: 0.0119 - val_loss: 0.0777
# Epoch 70/100
# 29/29 - 0s - 8ms/step - loss: 0.0123 - val_loss: 0.0801
# Epoch 71/100
# 29/29 - 0s - 7ms/step - loss: 0.0128 - val_loss: 0.0781
# Epoch 72/100
# 29/29 - 0s - 8ms/step - loss: 0.0120 - val_loss: 0.0735
# Epoch 73/100
# 29/29 - 0s - 10ms/step - loss: 0.0116 - val_loss: 0.0688
# Epoch 74/100
# 29/29 - 0s - 7ms/step - loss: 0.0115 - val_loss: 0.0676
# Epoch 75/100
# 29/29 - 0s - 7ms/step - loss: 0.0112 - val_loss: 0.0692
# Epoch 76/100
# 29/29 - 0s - 7ms/step - loss: 0.0110 - val_loss: 0.0685
# Epoch 77/100
# 29/29 - 0s - 8ms/step - loss: 0.0109 - val_loss: 0.0662
# Epoch 78/100
# 29/29 - 0s - 8ms/step - loss: 0.0111 - val_loss: 0.0659
# Epoch 79/100
# 29/29 - 0s - 7ms/step - loss: 0.0120 - val_loss: 0.0694
# Epoch 80/100
# 29/29 - 0s - 7ms/step - loss: 0.0148 - val_loss: 0.0766
# Epoch 81/100
# 29/29 - 0s - 8ms/step - loss: 0.0158 - val_loss: 0.0667
# Epoch 82/100
# 29/29 - 0s - 8ms/step - loss: 0.0123 - val_loss: 0.0758
# Epoch 83/100
# 29/29 - 0s - 10ms/step - loss: 0.0156 - val_loss: 0.0874
# Epoch 84/100
# 29/29 - 0s - 11ms/step - loss: 0.0121 - val_loss: 0.0655
# Epoch 85/100
# 29/29 - 0s - 11ms/step - loss: 0.0131 - val_loss: 0.0647
# Epoch 86/100
# 29/29 - 0s - 10ms/step - loss: 0.0117 - val_loss: 0.0846
# Epoch 87/100
# 29/29 - 0s - 10ms/step - loss: 0.0110 - val_loss: 0.0760
# Epoch 88/100
# 29/29 - 0s - 11ms/step - loss: 0.0107 - val_loss: 0.0715
# Epoch 89/100
# 29/29 - 0s - 10ms/step - loss: 0.0107 - val_loss: 0.0721
# Epoch 90/100
# 29/29 - 0s - 7ms/step - loss: 0.0107 - val_loss: 0.0708
# Epoch 91/100
# 29/29 - 0s - 7ms/step - loss: 0.0106 - val_loss: 0.0679
# Epoch 92/100
# 29/29 - 0s - 7ms/step - loss: 0.0103 - val_loss: 0.0670
# Epoch 93/100
# 29/29 - 0s - 8ms/step - loss: 0.0102 - val_loss: 0.0676
# Epoch 94/100
# 29/29 - 0s - 7ms/step - loss: 0.0105 - val_loss: 0.0682
# Epoch 95/100
# 29/29 - 0s - 7ms/step - loss: 0.0118 - val_loss: 0.0701
# Epoch 96/100
# 29/29 - 0s - 7ms/step - loss: 0.0139 - val_loss: 0.0649
# Epoch 97/100
# 29/29 - 0s - 8ms/step - loss: 0.0111 - val_loss: 0.0660
# Epoch 98/100
# 29/29 - 0s - 8ms/step - loss: 0.0122 - val_loss: 0.0741
# Epoch 99/100
# 29/29 - 0s - 7ms/step - loss: 0.0116 - val_loss: 0.0749
# Epoch 100/100
# 29/29 - 0s - 7ms/step - loss: 0.0112 - val_loss: 0.0616
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7dff64067a60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# --------------------------------------------------

# %%
# Experimentos: probar distintas arquitecturas y combinaciones (ejecución opcional - puede ser costosa)
import pandas as pd
from tensorflow.keras import backend as K

rnn_types = [SimpleRNN, GRU, LSTM]
units_list = [25, 50]
seq_lengths = [40, 60]

# Hiperparámetros razonables propuestos
epochs = 20
batch_size = 32
validation_split = 0.2

results = []

for rnn in rnn_types:
    for units in units_list:
        for seq in seq_lengths:
            print(f"\nEvaluando: {rnn.__name__} | units={units} | seq={seq}")
            K.clear_session()
            model = create_rnn_model(units, (seq, 1), rnn)
            try:
                hist, metrics, y_pair = evaluate_model(model, close_prices, seq,
                                                      epochs=epochs,
                                                      batch_size=batch_size,
                                                      validation_split=validation_split)
            except Exception as e:
                print('Error en evaluación:', e)
                continue
            row = {
                'rnn_type': rnn.__name__,
                'units': units,
                'seq_len': seq,
                'mape': metrics['mape'],
                'mse': metrics['mse'],
                'mae': metrics['mae'],
                'n_params': metrics['n_params']
            }
            results.append(row)

# Mostrar resultados ordenados por MAPE
if results:
    df_res = pd.DataFrame(results).sort_values('mape')
    print('\nResultados ordenados por MAPE:')
    display(df_res)
else:
    print('No hay resultados (tal vez los experimentos se omitieron o fallaron).')

print('\nNota: usar estas combinaciones con mayor número de épocas puede mejorar el ajuste; sin embargo, aumentará el tiempo de cómputo. Verifique sobreajuste comparando train vs val en `hist.history` si decide entrenar más.')
# Out:
# Evaluando: SimpleRNN | units=25 | seq=40
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 30/30 - 3s - 108ms/step - loss: 1.0165 - val_loss: 7.8141
# Epoch 2/20
# 30/30 - 0s - 7ms/step - loss: 0.1562 - val_loss: 4.2610
# Epoch 3/20
# 30/30 - 0s - 7ms/step - loss: 0.0838 - val_loss: 3.0649
# Epoch 4/20
# 30/30 - 0s - 6ms/step - loss: 0.0570 - val_loss: 2.3857
# Epoch 5/20
# 30/30 - 0s - 7ms/step - loss: 0.0411 - val_loss: 1.9777
# Epoch 6/20
# 30/30 - 0s - 7ms/step - loss: 0.0331 - val_loss: 1.7083
# Epoch 7/20
# 30/30 - 0s - 7ms/step - loss: 0.0286 - val_loss: 1.5163
# Epoch 8/20
# 30/30 - 0s - 7ms/step - loss: 0.0253 - val_loss: 1.3713
# Epoch 9/20
# 30/30 - 0s - 8ms/step - loss: 0.0228 - val_loss: 1.2583
# Epoch 10/20
# 30/30 - 0s - 8ms/step - loss: 0.0210 - val_loss: 1.1675
# Epoch 11/20
# 30/30 - 0s - 7ms/step - loss: 0.0197 - val_loss: 1.0919
# Epoch 12/20
# 30/30 - 0s - 8ms/step - loss: 0.0186 - val_loss: 1.0272
# Epoch 13/20
# 30/30 - 0s - 8ms/step - loss: 0.0177 - val_loss: 0.9709
# Epoch 14/20
# 30/30 - 0s - 8ms/step - loss: 0.0170 - val_loss: 0.9218
# Epoch 15/20
# 30/30 - 0s - 9ms/step - loss: 0.0164 - val_loss: 0.8785
# Epoch 16/20
# 30/30 - 0s - 10ms/step - loss: 0.0160 - val_loss: 0.8400
# Epoch 17/20
# 30/30 - 0s - 10ms/step - loss: 0.0156 - val_loss: 0.8053
# Epoch 18/20
# 30/30 - 1s - 22ms/step - loss: 0.0152 - val_loss: 0.7743
# Epoch 19/20
# 30/30 - 0s - 10ms/step - loss: 0.0149 - val_loss: 0.7462
# Epoch 20/20
# 30/30 - 0s - 8ms/step - loss: 0.0147 - val_loss: 0.7207
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7dff6d07d260> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step
#
# Evaluando: SimpleRNN | units=25 | seq=60
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 29/29 - 2s - 83ms/step - loss: 0.8325 - val_loss: 9.2352
# Epoch 2/20
# 29/29 - 0s - 10ms/step - loss: 0.2788 - val_loss: 6.3329
# Epoch 3/20
# 29/29 - 0s - 10ms/step - loss: 0.1357 - val_loss: 4.7015
# Epoch 4/20
# 29/29 - 0s - 9ms/step - loss: 0.0888 - val_loss: 3.7143
# Epoch 5/20
# 29/29 - 0s - 9ms/step - loss: 0.0646 - val_loss: 3.0539
# Epoch 6/20
# 29/29 - 0s - 9ms/step - loss: 0.0526 - val_loss: 2.6138
# Epoch 7/20
# 29/29 - 0s - 8ms/step - loss: 0.0453 - val_loss: 2.3019
# Epoch 8/20
# 29/29 - 0s - 8ms/step - loss: 0.0397 - val_loss: 2.0653
# Epoch 9/20
# 29/29 - 0s - 8ms/step - loss: 0.0355 - val_loss: 1.8796
# Epoch 10/20
# 29/29 - 0s - 8ms/step - loss: 0.0323 - val_loss: 1.7283
# Epoch 11/20
# 29/29 - 0s - 9ms/step - loss: 0.0299 - val_loss: 1.6027
# Epoch 12/20
# 29/29 - 0s - 8ms/step - loss: 0.0279 - val_loss: 1.4980
# Epoch 13/20
# 29/29 - 0s - 8ms/step - loss: 0.0263 - val_loss: 1.4102
# Epoch 14/20
# 29/29 - 0s - 8ms/step - loss: 0.0250 - val_loss: 1.3353
# Epoch 15/20
# 29/29 - 0s - 9ms/step - loss: 0.0238 - val_loss: 1.2703
# Epoch 16/20
# 29/29 - 0s - 9ms/step - loss: 0.0228 - val_loss: 1.2129
# Epoch 17/20
# 29/29 - 0s - 8ms/step - loss: 0.0219 - val_loss: 1.1617
# Epoch 18/20
# 29/29 - 0s - 8ms/step - loss: 0.0211 - val_loss: 1.1155
# Epoch 19/20
# 29/29 - 0s - 8ms/step - loss: 0.0204 - val_loss: 1.0733
# Epoch 20/20
# 29/29 - 0s - 8ms/step - loss: 0.0198 - val_loss: 1.0346
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step
#
# Evaluando: SimpleRNN | units=50 | seq=40
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 30/30 - 4s - 123ms/step - loss: 0.2190 - val_loss: 5.0183
# Epoch 2/20
# 30/30 - 0s - 7ms/step - loss: 0.0800 - val_loss: 2.1266
# Epoch 3/20
# 30/30 - 0s - 7ms/step - loss: 0.0573 - val_loss: 1.6304
# Epoch 4/20
# 30/30 - 0s - 7ms/step - loss: 0.0436 - val_loss: 1.2589
# Epoch 5/20
# 30/30 - 0s - 7ms/step - loss: 0.0388 - val_loss: 1.0579
# Epoch 6/20
# 30/30 - 0s - 7ms/step - loss: 0.0485 - val_loss: 1.0316
# Epoch 7/20
# 30/30 - 0s - 8ms/step - loss: 0.0302 - val_loss: 1.1343
# Epoch 8/20
# 30/30 - 0s - 8ms/step - loss: 0.0237 - val_loss: 0.9528
# Epoch 9/20
# 30/30 - 0s - 8ms/step - loss: 0.0215 - val_loss: 0.8582
# Epoch 10/20
# 30/30 - 0s - 8ms/step - loss: 0.0204 - val_loss: 0.7861
# Epoch 11/20
# 30/30 - 0s - 8ms/step - loss: 0.0194 - val_loss: 0.7186
# Epoch 12/20
# 30/30 - 0s - 8ms/step - loss: 0.0186 - val_loss: 0.6616
# Epoch 13/20
# 30/30 - 0s - 8ms/step - loss: 0.0179 - val_loss: 0.6129
# Epoch 14/20
# 30/30 - 0s - 8ms/step - loss: 0.0173 - val_loss: 0.5712
# Epoch 15/20
# 30/30 - 0s - 8ms/step - loss: 0.0167 - val_loss: 0.5348
# Epoch 16/20
# 30/30 - 0s - 8ms/step - loss: 0.0162 - val_loss: 0.5030
# Epoch 17/20
# 30/30 - 0s - 8ms/step - loss: 0.0157 - val_loss: 0.4748
# Epoch 18/20
# 30/30 - 0s - 8ms/step - loss: 0.0154 - val_loss: 0.4498
# Epoch 19/20
# 30/30 - 0s - 7ms/step - loss: 0.0150 - val_loss: 0.4275
# Epoch 20/20
# 30/30 - 0s - 7ms/step - loss: 0.0147 - val_loss: 0.4077
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step
#
# Evaluando: SimpleRNN | units=50 | seq=60
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 29/29 - 2s - 80ms/step - loss: 0.1445 - val_loss: 2.0001
# Epoch 2/20
# 29/29 - 0s - 10ms/step - loss: 0.0661 - val_loss: 1.0875
# Epoch 3/20
# 29/29 - 0s - 9ms/step - loss: 0.0470 - val_loss: 0.8153
# Epoch 4/20
# 29/29 - 0s - 9ms/step - loss: 0.0245 - val_loss: 0.6406
# Epoch 5/20
# 29/29 - 0s - 9ms/step - loss: 0.0175 - val_loss: 0.6656
# Epoch 6/20
# 29/29 - 0s - 9ms/step - loss: 0.0158 - val_loss: 0.5557
# Epoch 7/20
# 29/29 - 0s - 10ms/step - loss: 0.0148 - val_loss: 0.4899
# Epoch 8/20
# 29/29 - 0s - 10ms/step - loss: 0.0134 - val_loss: 0.4852
# Epoch 9/20
# 29/29 - 0s - 11ms/step - loss: 0.0131 - val_loss: 0.4690
# Epoch 10/20
# 29/29 - 1s - 21ms/step - loss: 0.0128 - val_loss: 0.4306
# Epoch 11/20
# 29/29 - 0s - 10ms/step - loss: 0.0126 - val_loss: 0.4092
# Epoch 12/20
# 29/29 - 0s - 9ms/step - loss: 0.0122 - val_loss: 0.3939
# Epoch 13/20
# 29/29 - 0s - 8ms/step - loss: 0.0119 - val_loss: 0.3772
# Epoch 14/20
# 29/29 - 0s - 8ms/step - loss: 0.0117 - val_loss: 0.3598
# Epoch 15/20
# 29/29 - 0s - 8ms/step - loss: 0.0115 - val_loss: 0.3440
# Epoch 16/20
# 29/29 - 0s - 8ms/step - loss: 0.0114 - val_loss: 0.3304
# Epoch 17/20
# 29/29 - 0s - 8ms/step - loss: 0.0112 - val_loss: 0.3182
# Epoch 18/20
# 29/29 - 0s - 8ms/step - loss: 0.0110 - val_loss: 0.3068
# Epoch 19/20
# 29/29 - 0s - 9ms/step - loss: 0.0109 - val_loss: 0.2960
# Epoch 20/20
# 29/29 - 0s - 8ms/step - loss: 0.0108 - val_loss: 0.2860
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step
#
# Evaluando: GRU | units=25 | seq=40
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 30/30 - 1s - 44ms/step - loss: 0.2116 - val_loss: 2.2524
# Epoch 2/20
# 30/30 - 0s - 9ms/step - loss: 0.0265 - val_loss: 0.9754
# Epoch 3/20
# 30/30 - 0s - 8ms/step - loss: 0.0257 - val_loss: 0.9532
# Epoch 4/20
# 30/30 - 0s - 8ms/step - loss: 0.0229 - val_loss: 0.8745
# Epoch 5/20
# 30/30 - 0s - 7ms/step - loss: 0.0218 - val_loss: 0.7998
# Epoch 6/20
# 30/30 - 0s - 8ms/step - loss: 0.0205 - val_loss: 0.7361
# Epoch 7/20
# 30/30 - 0s - 7ms/step - loss: 0.0195 - val_loss: 0.6771
# Epoch 8/20
# 30/30 - 0s - 8ms/step - loss: 0.0185 - val_loss: 0.6245
# Epoch 9/20
# 30/30 - 0s - 10ms/step - loss: 0.0178 - val_loss: 0.5778
# Epoch 10/20
# 30/30 - 0s - 8ms/step - loss: 0.0171 - val_loss: 0.5348
# Epoch 11/20
# 30/30 - 0s - 7ms/step - loss: 0.0165 - val_loss: 0.4974
# Epoch 12/20
# 30/30 - 0s - 8ms/step - loss: 0.0159 - val_loss: 0.4619
# Epoch 13/20
# 30/30 - 0s - 7ms/step - loss: 0.0154 - val_loss: 0.4315
# Epoch 14/20
# 30/30 - 0s - 8ms/step - loss: 0.0149 - val_loss: 0.4018
# Epoch 15/20
# 30/30 - 0s - 8ms/step - loss: 0.0145 - val_loss: 0.3768
# Epoch 16/20
# 30/30 - 0s - 7ms/step - loss: 0.0141 - val_loss: 0.3519
# Epoch 17/20
# 30/30 - 0s - 8ms/step - loss: 0.0138 - val_loss: 0.3311
# Epoch 18/20
# 30/30 - 0s - 7ms/step - loss: 0.0135 - val_loss: 0.3101
# Epoch 19/20
# 30/30 - 0s - 7ms/step - loss: 0.0132 - val_loss: 0.2925
# Epoch 20/20
# 30/30 - 0s - 7ms/step - loss: 0.0129 - val_loss: 0.2750
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Evaluando: GRU | units=25 | seq=60
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 29/29 - 2s - 53ms/step - loss: 0.6878 - val_loss: 6.3137
# Epoch 2/20
# 29/29 - 0s - 11ms/step - loss: 0.1726 - val_loss: 3.0540
# Epoch 3/20
# 29/29 - 0s - 11ms/step - loss: 0.0392 - val_loss: 1.7403
# Epoch 4/20
# 29/29 - 1s - 19ms/step - loss: 0.0329 - val_loss: 1.4649
# Epoch 5/20
# 29/29 - 0s - 8ms/step - loss: 0.0301 - val_loss: 1.4020
# Epoch 6/20
# 29/29 - 0s - 7ms/step - loss: 0.0281 - val_loss: 1.2932
# Epoch 7/20
# 29/29 - 0s - 7ms/step - loss: 0.0266 - val_loss: 1.2016
# Epoch 8/20
# 29/29 - 0s - 7ms/step - loss: 0.0252 - val_loss: 1.1206
# Epoch 9/20
# 29/29 - 0s - 8ms/step - loss: 0.0240 - val_loss: 1.0478
# Epoch 10/20
# 29/29 - 0s - 7ms/step - loss: 0.0230 - val_loss: 0.9828
# Epoch 11/20
# 29/29 - 0s - 7ms/step - loss: 0.0221 - val_loss: 0.9244
# Epoch 12/20
# 29/29 - 0s - 7ms/step - loss: 0.0213 - val_loss: 0.8718
# Epoch 13/20
# 29/29 - 0s - 7ms/step - loss: 0.0206 - val_loss: 0.8242
# Epoch 14/20
# 29/29 - 0s - 7ms/step - loss: 0.0199 - val_loss: 0.7810
# Epoch 15/20
# 29/29 - 0s - 8ms/step - loss: 0.0194 - val_loss: 0.7417
# Epoch 16/20
# 29/29 - 0s - 7ms/step - loss: 0.0188 - val_loss: 0.7057
# Epoch 17/20
# 29/29 - 0s - 7ms/step - loss: 0.0183 - val_loss: 0.6727
# Epoch 18/20
# 29/29 - 0s - 7ms/step - loss: 0.0179 - val_loss: 0.6424
# Epoch 19/20
# 29/29 - 0s - 7ms/step - loss: 0.0175 - val_loss: 0.6144
# Epoch 20/20
# 29/29 - 0s - 7ms/step - loss: 0.0171 - val_loss: 0.5886
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# Evaluando: GRU | units=50 | seq=40
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 30/30 - 1s - 41ms/step - loss: 0.6430 - val_loss: 4.4674
# Epoch 2/20
# 30/30 - 0s - 8ms/step - loss: 0.0336 - val_loss: 0.8385
# Epoch 3/20
# 30/30 - 0s - 7ms/step - loss: 0.0325 - val_loss: 0.8064
# Epoch 4/20
# 30/30 - 0s - 7ms/step - loss: 0.0266 - val_loss: 0.6445
# Epoch 5/20
# 30/30 - 0s - 7ms/step - loss: 0.0230 - val_loss: 0.5726
# Epoch 6/20
# 30/30 - 0s - 8ms/step - loss: 0.0229 - val_loss: 0.5234
# Epoch 7/20
# 30/30 - 0s - 8ms/step - loss: 0.0207 - val_loss: 0.4454
# Epoch 8/20
# 30/30 - 0s - 8ms/step - loss: 0.0202 - val_loss: 0.4242
# Epoch 9/20
# 30/30 - 0s - 7ms/step - loss: 0.0192 - val_loss: 0.3730
# Epoch 10/20
# 30/30 - 0s - 8ms/step - loss: 0.0184 - val_loss: 0.3500
# Epoch 11/20
# 30/30 - 0s - 8ms/step - loss: 0.0179 - val_loss: 0.3239
# Epoch 12/20
# 30/30 - 0s - 7ms/step - loss: 0.0172 - val_loss: 0.2969
# Epoch 13/20
# 30/30 - 0s - 7ms/step - loss: 0.0168 - val_loss: 0.2826
# Epoch 14/20
# 30/30 - 0s - 7ms/step - loss: 0.0163 - val_loss: 0.2596
# Epoch 15/20
# 30/30 - 0s - 8ms/step - loss: 0.0159 - val_loss: 0.2463
# Epoch 16/20
# 30/30 - 0s - 7ms/step - loss: 0.0155 - val_loss: 0.2314
# Epoch 17/20
# 30/30 - 0s - 7ms/step - loss: 0.0151 - val_loss: 0.2171
# Epoch 18/20
# 30/30 - 0s - 7ms/step - loss: 0.0149 - val_loss: 0.2071
# Epoch 19/20
# 30/30 - 0s - 8ms/step - loss: 0.0146 - val_loss: 0.1951
# Epoch 20/20
# 30/30 - 0s - 7ms/step - loss: 0.0143 - val_loss: 0.1862
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# Evaluando: GRU | units=50 | seq=60
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 29/29 - 2s - 56ms/step - loss: 0.4862 - val_loss: 2.8600
# Epoch 2/20
# 29/29 - 0s - 8ms/step - loss: 0.0379 - val_loss: 0.6341
# Epoch 3/20
# 29/29 - 0s - 8ms/step - loss: 0.0272 - val_loss: 0.6021
# Epoch 4/20
# 29/29 - 0s - 8ms/step - loss: 0.0261 - val_loss: 0.5148
# Epoch 5/20
# 29/29 - 0s - 8ms/step - loss: 0.0239 - val_loss: 0.4504
# Epoch 6/20
# 29/29 - 0s - 8ms/step - loss: 0.0231 - val_loss: 0.4077
# Epoch 7/20
# 29/29 - 0s - 7ms/step - loss: 0.0218 - val_loss: 0.3582
# Epoch 8/20
# 29/29 - 0s - 8ms/step - loss: 0.0210 - val_loss: 0.3308
# Epoch 9/20
# 29/29 - 0s - 7ms/step - loss: 0.0203 - val_loss: 0.2990
# Epoch 10/20
# 29/29 - 0s - 7ms/step - loss: 0.0195 - val_loss: 0.2755
# Epoch 11/20
# 29/29 - 0s - 7ms/step - loss: 0.0190 - val_loss: 0.2565
# Epoch 12/20
# 29/29 - 0s - 7ms/step - loss: 0.0183 - val_loss: 0.2359
# Epoch 13/20
# 29/29 - 0s - 8ms/step - loss: 0.0179 - val_loss: 0.2227
# Epoch 14/20
# 29/29 - 0s - 7ms/step - loss: 0.0174 - val_loss: 0.2071
# Epoch 15/20
# 29/29 - 0s - 7ms/step - loss: 0.0169 - val_loss: 0.1953
# Epoch 16/20
# 29/29 - 0s - 7ms/step - loss: 0.0166 - val_loss: 0.1848
# Epoch 17/20
# 29/29 - 0s - 7ms/step - loss: 0.0162 - val_loss: 0.1739
# Epoch 18/20
# 29/29 - 0s - 9ms/step - loss: 0.0159 - val_loss: 0.1660
# Epoch 19/20
# 29/29 - 0s - 7ms/step - loss: 0.0156 - val_loss: 0.1576
# Epoch 20/20
# 29/29 - 0s - 7ms/step - loss: 0.0153 - val_loss: 0.1506
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
# Evaluando: LSTM | units=25 | seq=40
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 30/30 - 1s - 45ms/step - loss: 0.2786 - val_loss: 5.1213
# Epoch 2/20
# 30/30 - 0s - 8ms/step - loss: 0.0899 - val_loss: 2.8817
# Epoch 3/20
# 30/30 - 0s - 8ms/step - loss: 0.0620 - val_loss: 2.2181
# Epoch 4/20
# 30/30 - 0s - 8ms/step - loss: 0.0483 - val_loss: 1.7997
# Epoch 5/20
# 30/30 - 0s - 7ms/step - loss: 0.0429 - val_loss: 1.4731
# Epoch 6/20
# 30/30 - 0s - 7ms/step - loss: 0.0383 - val_loss: 1.2622
# Epoch 7/20
# 30/30 - 0s - 8ms/step - loss: 0.0359 - val_loss: 1.0973
# Epoch 8/20
# 30/30 - 0s - 7ms/step - loss: 0.0335 - val_loss: 0.9804
# Epoch 9/20
# 30/30 - 0s - 8ms/step - loss: 0.0319 - val_loss: 0.8783
# Epoch 10/20
# 30/30 - 0s - 7ms/step - loss: 0.0304 - val_loss: 0.7991
# Epoch 11/20
# 30/30 - 0s - 8ms/step - loss: 0.0292 - val_loss: 0.7283
# Epoch 12/20
# 30/30 - 0s - 10ms/step - loss: 0.0281 - val_loss: 0.6692
# Epoch 13/20
# 30/30 - 0s - 8ms/step - loss: 0.0271 - val_loss: 0.6185
# Epoch 14/20
# 30/30 - 0s - 8ms/step - loss: 0.0263 - val_loss: 0.5721
# Epoch 15/20
# 30/30 - 0s - 7ms/step - loss: 0.0253 - val_loss: 0.5348
# Epoch 16/20
# 30/30 - 0s - 8ms/step - loss: 0.0247 - val_loss: 0.4975
# Epoch 17/20
# 30/30 - 0s - 10ms/step - loss: 0.0237 - val_loss: 0.4685
# Epoch 18/20
# 30/30 - 0s - 10ms/step - loss: 0.0233 - val_loss: 0.4394
# Epoch 19/20
# 30/30 - 0s - 11ms/step - loss: 0.0222 - val_loss: 0.4147
# Epoch 20/20
# 30/30 - 0s - 11ms/step - loss: 0.0220 - val_loss: 0.3944
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# Evaluando: LSTM | units=25 | seq=60
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 29/29 - 1s - 46ms/step - loss: 0.8013 - val_loss: 7.7770
# Epoch 2/20
# 29/29 - 0s - 8ms/step - loss: 0.1939 - val_loss: 4.6833
# Epoch 3/20
# 29/29 - 0s - 8ms/step - loss: 0.1462 - val_loss: 3.5306
# Epoch 4/20
# 29/29 - 0s - 7ms/step - loss: 0.0937 - val_loss: 2.7662
# Epoch 5/20
# 29/29 - 0s - 8ms/step - loss: 0.0788 - val_loss: 2.2811
# Epoch 6/20
# 29/29 - 0s - 7ms/step - loss: 0.0650 - val_loss: 1.9449
# Epoch 7/20
# 29/29 - 0s - 7ms/step - loss: 0.0593 - val_loss: 1.6745
# Epoch 8/20
# 29/29 - 0s - 7ms/step - loss: 0.0529 - val_loss: 1.4929
# Epoch 9/20
# 29/29 - 0s - 7ms/step - loss: 0.0494 - val_loss: 1.3385
# Epoch 10/20
# 29/29 - 0s - 8ms/step - loss: 0.0461 - val_loss: 1.2375
# Epoch 11/20
# 29/29 - 0s - 7ms/step - loss: 0.0435 - val_loss: 1.1399
# Epoch 12/20
# 29/29 - 0s - 7ms/step - loss: 0.0417 - val_loss: 1.0755
# Epoch 13/20
# 29/29 - 0s - 8ms/step - loss: 0.0397 - val_loss: 1.0071
# Epoch 14/20
# 29/29 - 0s - 7ms/step - loss: 0.0386 - val_loss: 0.9592
# Epoch 15/20
# 29/29 - 0s - 8ms/step - loss: 0.0369 - val_loss: 0.9087
# Epoch 16/20
# 29/29 - 0s - 8ms/step - loss: 0.0360 - val_loss: 0.8683
# Epoch 17/20
# 29/29 - 0s - 8ms/step - loss: 0.0347 - val_loss: 0.8306
# Epoch 18/20
# 29/29 - 0s - 7ms/step - loss: 0.0339 - val_loss: 0.7936
# Epoch 19/20
# 29/29 - 0s - 8ms/step - loss: 0.0329 - val_loss: 0.7653
# Epoch 20/20
# 29/29 - 0s - 7ms/step - loss: 0.0320 - val_loss: 0.7306
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# Evaluando: LSTM | units=50 | seq=40
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 30/30 - 1s - 47ms/step - loss: 0.2754 - val_loss: 3.3031
# Epoch 2/20
# 30/30 - 0s - 8ms/step - loss: 0.1006 - val_loss: 1.3022
# Epoch 3/20
# 30/30 - 0s - 8ms/step - loss: 0.0904 - val_loss: 0.9946
# Epoch 4/20
# 30/30 - 0s - 8ms/step - loss: 0.0576 - val_loss: 0.8764
# Epoch 5/20
# 30/30 - 0s - 8ms/step - loss: 0.0502 - val_loss: 0.7190
# Epoch 6/20
# 30/30 - 0s - 8ms/step - loss: 0.0490 - val_loss: 0.6874
# Epoch 7/20
# 30/30 - 0s - 7ms/step - loss: 0.0393 - val_loss: 0.5559
# Epoch 8/20
# 30/30 - 0s - 7ms/step - loss: 0.0380 - val_loss: 0.5320
# Epoch 9/20
# 30/30 - 0s - 8ms/step - loss: 0.0332 - val_loss: 0.4495
# Epoch 10/20
# 30/30 - 0s - 10ms/step - loss: 0.0324 - val_loss: 0.4165
# Epoch 11/20
# 30/30 - 0s - 8ms/step - loss: 0.0290 - val_loss: 0.3661
# Epoch 12/20
# 30/30 - 0s - 11ms/step - loss: 0.0288 - val_loss: 0.3400
# Epoch 13/20
# 30/30 - 1s - 20ms/step - loss: 0.0267 - val_loss: 0.2999
# Epoch 14/20
# 30/30 - 0s - 11ms/step - loss: 0.0265 - val_loss: 0.2840
# Epoch 15/20
# 30/30 - 0s - 15ms/step - loss: 0.0256 - val_loss: 0.2527
# Epoch 16/20
# 30/30 - 0s - 14ms/step - loss: 0.0240 - val_loss: 0.2299
# Epoch 17/20
# 30/30 - 0s - 8ms/step - loss: 0.0244 - val_loss: 0.2276
# Epoch 18/20
# 30/30 - 0s - 9ms/step - loss: 0.0227 - val_loss: 0.1905
# Epoch 19/20
# 30/30 - 0s - 8ms/step - loss: 0.0226 - val_loss: 0.1997
# Epoch 20/20
# 30/30 - 0s - 8ms/step - loss: 0.0225 - val_loss: 0.1780
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# Evaluando: LSTM | units=50 | seq=60
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 29/29 - 1s - 46ms/step - loss: 0.4230 - val_loss: 3.9498
# Epoch 2/20
# 29/29 - 0s - 8ms/step - loss: 0.1253 - val_loss: 1.3486
# Epoch 3/20
# 29/29 - 0s - 8ms/step - loss: 0.1085 - val_loss: 1.0245
# Epoch 4/20
# 29/29 - 0s - 7ms/step - loss: 0.0618 - val_loss: 0.8344
# Epoch 5/20
# 29/29 - 0s - 7ms/step - loss: 0.0554 - val_loss: 0.7810
# Epoch 6/20
# 29/29 - 0s - 8ms/step - loss: 0.0528 - val_loss: 0.6715
# Epoch 7/20
# 29/29 - 0s - 8ms/step - loss: 0.0478 - val_loss: 0.6074
# Epoch 8/20
# 29/29 - 0s - 8ms/step - loss: 0.0474 - val_loss: 0.5633
# Epoch 9/20
# 29/29 - 0s - 8ms/step - loss: 0.0428 - val_loss: 0.4859
# Epoch 10/20
# 29/29 - 0s - 7ms/step - loss: 0.0429 - val_loss: 0.4716
# Epoch 11/20
# 29/29 - 0s - 7ms/step - loss: 0.0383 - val_loss: 0.4000
# Epoch 12/20
# 29/29 - 0s - 8ms/step - loss: 0.0384 - val_loss: 0.3971
# Epoch 13/20
# 29/29 - 0s - 8ms/step - loss: 0.0344 - val_loss: 0.3381
# Epoch 14/20
# 29/29 - 0s - 7ms/step - loss: 0.0343 - val_loss: 0.3356
# Epoch 15/20
# 29/29 - 0s - 7ms/step - loss: 0.0310 - val_loss: 0.2921
# Epoch 16/20
# 29/29 - 0s - 8ms/step - loss: 0.0306 - val_loss: 0.2856
# Epoch 17/20
# 29/29 - 0s - 9ms/step - loss: 0.0281 - val_loss: 0.2574
# Epoch 18/20
# 29/29 - 0s - 7ms/step - loss: 0.0275 - val_loss: 0.2465
# Epoch 19/20
# 29/29 - 0s - 7ms/step - loss: 0.0255 - val_loss: 0.2312
# Epoch 20/20
# 29/29 - 0s - 7ms/step - loss: 0.0250 - val_loss: 0.2181
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# Resultados ordenados por MAPE:
#      rnn_type  units  seq_len      mape          mse        mae  n_params
# 7         GRU     50       60  0.040528  1288.861263  28.122174      8001
# 10       LSTM     50       40  0.044703  1548.842099  30.963855     10451
# 6         GRU     50       40  0.045069  1619.880184  31.464239      8001
# 11       LSTM     50       60  0.049210  1865.985251  34.181643     10451
# 3   SimpleRNN     50       60  0.053474  2447.076175  37.870165      2651
# 4         GRU     25       40  0.054015  2392.362717  38.070289      2126
# 2   SimpleRNN     50       40  0.064301  3546.364517  45.589859      2651
# 8        LSTM     25       40  0.065587  3431.238956  46.002671      2726
# 5         GRU     25       60  0.079089  5036.286290  56.145715      2126
# 0   SimpleRNN     25       40  0.083966  6270.017958  60.018989       701
# 9        LSTM     25       60  0.089227  6251.396522  62.967369      2726
# 1   SimpleRNN     25       60  0.104908  8852.824904  74.637249       701
# Nota: usar estas combinaciones con mayor número de épocas puede mejorar el ajuste; sin embargo, aumentará el tiempo de cómputo. Verifique sobreajuste comparando train vs val en `hist.history` si decide entrenar más.

# %% [markdown]
# # Análisis del impacto en la periodicidad del re-entrenamiento del modelo
#
# Para el modelo que mejor resultados haya obtenido en el punto anterior, analice el impacto de re-entrenar el mismo en cada instante de tiempo respecto a utilizarlo para predecir un lote completo de datos. Es decir, si se piensa en utilizar este modelo en la vida real, el mismo podría ser re-entrenado cada distintos períodos de tiempo (todos los días, una vez por semana, una vez al mes, etc.). Analice cómo variar dichos intervalos de re-entrenamiento afectan el rendimiento del modelo, seleccionado un período de tiempo determinado para dicha exploración.

# %%
# Evaluación del impacto de la frecuencia de re-entrenamiento (walk-forward)
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error, mean_absolute_error
from tensorflow.keras import backend as K


def walk_forward_retrain(rnn_class, units, seq_len, retrain_freq, initial_train_frac=0.6,
                         epochs=10, batch_size=32, sliding=False):
    """
    Simula re-entrenamientos cada `retrain_freq` días usando un esquema walk-forward.
    - rnn_class: SimpleRNN/GRU/LSTM class
    - units, seq_len: hiperparámetros del modelo
    - retrain_freq: número de días entre re-entrenamientos (1=diario, 7=semanal, 30=mensual)
    - initial_train_frac: fracción del dataset usada como entrenamiento inicial
    - sliding: si True usa ventana deslizante fija; si False usa ventana expansiva (todos los datos anteriores)

    Retorna: (metrics_dict, df_predictions)
    """
    # Obtener serie con índice temporal
    if 'ypf_data' in globals():
        series = ypf_data['Close'].dropna().astype(float)
    elif 'df' in globals():
        series = df['Close'].dropna().astype(float)
    else:
        raise RuntimeError('No se encontró la serie de precios (ejecute la celda de descarga).')

    n = len(series)
    initial_end = int(n * initial_train_frac)
    preds = []
    trues = []
    pred_dates = []

    t = initial_end
    while t < n:
        # definir ventana de entrenamiento
        if sliding:
            # ventana de tamaño initial_end (fija)
            start_idx = max(0, t - initial_end)
            train_series = series.iloc[start_idx:t]
        else:
            # ventana expansiva: desde inicio hasta t-1
            train_series = series.iloc[:t]

        # construir secuencias
        X_train, y_train = create_sequences(train_series.values.reshape(-1,1), seq_len)
        if len(X_train) == 0:
            t += retrain_freq
            continue

        # escalado ajustado sólo con train
        scaler = StandardScaler()
        X_train_flat = X_train.reshape(-1,1)
        scaler.fit(X_train_flat)
        X_train_s = scaler.transform(X_train_flat).reshape(X_train.shape)
        y_train_s = scaler.transform(y_train.reshape(-1,1)).reshape(-1,1)

        # crear y entrenar modelo
        K.clear_session()
        model = create_rnn_model(units, (seq_len, 1), rnn_class)
        model.fit(X_train_s, y_train_s, epochs=epochs, batch_size=batch_size, shuffle=False, verbose=0)

        # preparar input para predecir el siguiente día t
        if t - seq_len < 0:
            t += retrain_freq
            continue
        x_input = series.values[t-seq_len:t].reshape(1, seq_len, 1)
        x_input_s = scaler.transform(x_input.reshape(-1,1)).reshape(x_input.shape)
        y_pred_s = model.predict(x_input_s)
        y_pred = scaler.inverse_transform(y_pred_s).ravel()[0]
        y_true = series.values[t]

        preds.append(y_pred)
        trues.append(y_true)
        pred_dates.append(series.index[t])

        t += retrain_freq

    metrics = {}
    if len(preds) > 0:
        metrics['mape'] = mean_absolute_percentage_error(trues, preds)
        metrics['mse'] = mean_squared_error(trues, preds)
        metrics['mae'] = mean_absolute_error(trues, preds)
    else:
        metrics['mape'] = np.nan
        metrics['mse'] = np.nan
        metrics['mae'] = np.nan
    metrics['n_preds'] = len(preds)

    df_preds = pd.DataFrame({'Fecha': pred_dates, 'y_true': trues, 'y_pred': preds})

    return metrics, df_preds


# Seleccionar modelo "mejor" a partir de resultados previos si existen
if 'df_res' in globals() and not df_res.empty:
    best = df_res.iloc[0]
    rnn_name = best['rnn_type']
    units_best = int(best['units'])
    seq_best = int(best['seq_len'])
    rnn_class_best = {'SimpleRNN': SimpleRNN, 'GRU': GRU, 'LSTM': LSTM}[rnn_name]
    print(f"Usando mejor modelo detectado: {rnn_name} units={units_best} seq={seq_best}")
else:
    print('No se encontró `df_res` con resultados previos; usando configuración por defecto SimpleRNN(25, seq=40)')
    rnn_class_best = SimpleRNN
    units_best = 25
    seq_best = 40

# Frecuencias a comparar (días)
frecuencias = [1, 7, 30]
summary = []
all_preds = {}
for f in frecuencias:
    print(f"Evaluando re-entrenamiento cada {f} día(s) ...")
    metrics, dfp = walk_forward_retrain(rnn_class_best, units_best, seq_best, retrain_freq=f,
                                        initial_train_frac=0.6, epochs=10, batch_size=32, sliding=False)
    summary.append({'retrain_days': f, 'mape': metrics['mape'], 'mse': metrics['mse'], 'mae': metrics['mae'], 'n_preds': metrics['n_preds']})
    all_preds[f] = dfp

print('\nResumen de frecuencias de re-entrenamiento:')
df_summary = pd.DataFrame(summary).sort_values('mape')
display(df_summary)

# Graficar la mejor frecuencia
valid_rows = df_summary.dropna(subset=['mape'])
if not valid_rows.empty:
    best_f = int(valid_rows.iloc[0]['retrain_days'])
    print(f"Mejor frecuencia por MAPE: {best_f} días")
    df_best = all_preds[best_f]
    plt.figure(figsize=(12,4))
    plt.plot(df_best['Fecha'], df_best['y_true'], label='Real')
    plt.plot(df_best['Fecha'], df_best['y_pred'], label=f'Predicción (retrain cada {best_f}d)')
    plt.title('Real vs Predicción (mejor frecuencia)')
    plt.xlabel('Fecha')
    plt.ylabel('Precio')
    plt.legend()
    plt.grid(True)
    plt.show()
else:
    print('No se generaron predicciones para las frecuencias seleccionadas.')

print('\nObservaciones:')
print('- Un retrain más frecuente (p.ej. diario) permite actualizar el modelo con la información más reciente pero puede ser costoso en producción.')
print('- Un retrain menos frecuente (semanal/mensual) reduce coste computacional; si los mercados cambian rápidamente puede degradar la precisión.')
print("- Compare también el número de predicciones generadas (n_preds) y la estabilidad de la métrica para seleccionar la frecuencia adecuada.")
print('\nLimitaciones: esta simulación usa un esquema simple (one-step ahead) y un número reducido de épocas. Para decisiones de producción considere validación más amplia y control de sobreajuste (EarlyStopping, checkpointing).')
# Out:
# Usando mejor modelo detectado: GRU units=50 seq=60
# Evaluando re-entrenamiento cada 1 día(s) ...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# ...
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Evaluando re-entrenamiento cada 30 día(s) ...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
#
# Resumen de frecuencias de re-entrenamiento:
#    retrain_days      mape         mse        mae  n_preds
# 1             7  0.024743  350.958484  14.433046       70
# 2            30  0.027024  311.386817  15.157456       17
# 0             1  0.028255  443.436841  16.186950      489
# Mejor frecuencia por MAPE: 7 días
# Observaciones:
# - Un retrain más frecuente (p.ej. diario) permite actualizar el modelo con la información más reciente pero puede ser costoso en producción.
# - Un retrain menos frecuente (semanal/mensual) reduce coste computacional; si los mercados cambian rápidamente puede degradar la precisión.
# - Compare también el número de predicciones generadas (n_preds) y la estabilidad de la métrica para seleccionar la frecuencia adecuada.
#
# Limitaciones: esta simulación usa un esquema simple (one-step ahead) y un número reducido de épocas. Para decisiones de producción considere validación más amplia y control de sobreajuste (EarlyStopping, checkpointing).
